# %% [markdown]
# # PROCESSING

# %%
from pathlib import Path

# %%
base = Path('./')

post_patch_csvs = [f for f in base.rglob("process_list_autogen.csv") if f.parts[0] != "archived"]

post_feat_ext_csvs = [f for f in base.rglob("post_feat_ext.csv") if f.parts[0] != "archived"]

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
post_patch = pd.concat([
    pd.read_csv(csv) for csv in post_patch_csvs
])

post_patch["slide_id"] = post_patch["slide_id"].str.replace('.svs', '', regex=False)
post_patch["error"] = post_patch["error"].str[:20] # Truncate error message
post_patch.rename(columns={'slide_id':'image_id'}, inplace=True)

# Already existing ones here can be interpretted as patched
post_patch.loc[
    (post_patch["status"] == "processed") | (post_patch["status"] == "already_exist"), "status"
] = "patched"
    
    

post_feat_ext = pd.concat([
    pd.read_csv(csv) for csv in post_feat_ext_csvs
])

post_feat_ext["slide_id"] = post_feat_ext["slide_id"].str.replace('.svs', '', regex=False)
post_feat_ext["error"] = post_feat_ext["error"].str[-20:] # Truncate error message
post_feat_ext.rename(columns={'slide_id':'image_id'}, inplace=True)

# Already existing ones here can be interpretted as features extracted
post_feat_ext.loc[
    post_feat_ext["status"] == "already_exist", "status"
] = "features_extracted"

# %%
post_patch.head()
# Out:
#         image_id  process   status  seg_level  sthresh  mthresh  close  \
# 0  PATH000001432        0  patched         -2        8        3      4
# 1  PATH000001472        0  patched         -2        8        3      4
# 2  PATH000001571        0  patched         -2        8        3      4
# 3  PATH000001583        0  patched         -2        8        3      4
# 4  PATH000001588        0  patched         -2        8        3      4
#
#    use_otsu keep_ids exclude_ids  a_t  a_h  max_n_holes  vis_level  \
# 0      True     none        none  1.0  1.0            8         -1
# 1      True     none        none  1.0  1.0            8         -1
# 2      True     none        none  1.0  1.0            8         -1
# 3      True     none        none  1.0  1.0            8         -1
# 4      True     none        none  1.0  1.0            8         -1
#
#    line_thickness  use_padding contour_fn error
# 0             100         True    four_pt   NaN
# 1             100         True    four_pt   NaN
# 2             100         True    four_pt   NaN
# 3             100         True    four_pt   NaN
# 4             100         True    four_pt   NaN

# %%
master = pd.read_csv("labels.csv")

master.head()
# Out:
#         image_id  usable    label site_label expert_label expert_label_other  \
# 0  PATH000000291       0  Missing    Missing
# 1  PATH000000452       0  Missing    Missing
# 2  PATH000001313       0  Missing    Missing
# 3  PATH000001317       0  Missing    Missing
# 4  PATH000001376       0  Missing    Missing
#
#   expert_label_notes country patient_id  svs_delivered
# 0                          .                         1
# 1                          .                         1
# 2                          .                         1
# 3                          .                         1
# 4                          .                         1

# %%
master['status'] = "tbp"
master['error'] = pd.NA
master_i = master.set_index('image_id')

post_patch_i = post_patch.set_index('image_id')
master_i.update(post_patch_i[['status', 'error']])

post_feat_ext_i = post_feat_ext.set_index('image_id')
master_i.update(post_feat_ext_i[['status', 'error']])
    
master = master_i.reset_index()

# %% [markdown]
# ### We decided that we'll only use the images that Diego has reviewed, so we need to update the usable flag. ALSO WE ARE EXCLUDING MALAWI NORMALS

# %%
master.loc[
    master['expert_label'] == " ", 'usable'
] = 0

# %% [markdown]
# Let's see the label distribution over countries, looks like Malawi has a lot of the Negative/Reactive. And if we have to downsample it does make sense to me to exclude these ones systematically.

# %%
master.loc[
    (master['country'] == "Malawi") & (master['label'] == "Negative/Reactive"), 'usable'
] = 0

# %%
len(master[
    (master['country'] == "Malawi") & (master['label'] == "Negative/Reactive") & (master.usable) & (master.status != "tbp")
])
# Out:
# 0

# %%
master.status.value_counts()
# Out:
# status
# tbp                   7813
# features_extracted    7530
# failed_seg             286
# failed_ext              40
# Name: count, dtype: int64

# %%
master.head()
# Out:
#         image_id  usable    label site_label expert_label expert_label_other  \
# 0  PATH000000291       0  Missing    Missing
# 1  PATH000000452       0  Missing    Missing
# 2  PATH000001313       0  Missing    Missing
# 3  PATH000001317       0  Missing    Missing
# 4  PATH000001376       0  Missing    Missing
#
#   expert_label_notes country patient_id  svs_delivered status error
# 0                          .                         1    tbp  <NA>
# 1                          .                         1    tbp  <NA>
# 2                          .                         1    tbp  <NA>
# 3                          .                         1    tbp  <NA>
# 4                          .                         1    tbp  <NA>

# %% [markdown]
# # EXPLORATION

# %% [markdown]
# ### Let's see if the svs_delivered flag is accurate for the samples we've processed thus far.

# %%
master.groupby(['svs_delivered','status']).size()
# Out:
# svs_delivered  status
# 0              tbp                   4216
# 1              failed_ext              40
#                failed_seg             286
#                features_extracted    7530
#                tbp                   3597
# dtype: int64

# %% [markdown]
# ### Let's see how much of what we've done we can actually use

# %%
master.groupby('usable')['status'].value_counts()
# Out:
# usable  status
# 0       tbp                   5463
#         features_extracted    4092
#         failed_seg             132
#         failed_ext              19
# 1       features_extracted    3438
#         tbp                   2350
#         failed_seg             154
#         failed_ext              21
# Name: count, dtype: int64

# %%
master.groupby(['svs_delivered','usable']).size()
# Out:
# svs_delivered  usable
# 0              0         4216
# 1              0         5490
#                1         5963
# dtype: int64

# %% [markdown]
# # PROCESSING
#
# ### Grouping labels

# %%
master.loc[
    master.expert_label == "Insufficient/Inadequate", 'label'
] = "insufficient"

# %%
master.loc[
    master.expert_label == "Atypia: Specify", 'label'
] = 'atypia'

# %%
master.loc[
    master.expert_label == "Other: Specify", 'label'
] = 'other'

# %%
master.loc[
    master.expert_label == 'CIN1', 'label'
] = 'low_grade'

# %%
master.loc[
    master.expert_label.isin(['CIN2','CIN3','AIS']), 'label'
] = 'high_grade'

# %%
master.loc[
    master.expert_label.isin([
        'Adenocarcinoma Invasive','Adenosquamous Carcinoma','Other Cancer: Specify','Squamous Invasive Carcinoma'
    ]) | 
    (
        (master.expert_label == "Other: Specify") & 
        (master.expert_label_other.str.contains("carcinoma", case=False)) &
        (~master.expert_label_other.str.contains("rule out", case=False))
    )  
    , 'label'
] = 'cancer'

# %%
master.loc[
    (master.expert_label == "Negative/Reactive") |
    (
        (master.expert_label == "Other: Specify") &
        (master.expert_label_other.str.contains("microglandular hyperplasia", case=False))
    ),
    'label'
] = 'normal'

# %% [markdown]
# ### We discard other and atypia

# %%
master.loc[
    (master.label == "other") | (master.label == "atypia"),
    'usable'
] = 0

# %%
len(master[(master.label == "other") | (master.label == "atypia")])
# Out:
# 75

# %%
master.groupby('usable')['status'].value_counts()
# Out:
# usable  status
# 0       tbp                   5483
#         features_extracted    4137
#         failed_seg             134
#         failed_ext              19
# 1       features_extracted    3393
#         tbp                   2330
#         failed_seg             152
#         failed_ext              21
# Name: count, dtype: int64

# %% [markdown]
# # EXPLORATION
#
# ### Let's see the label distributions over the samples we can use.

# %%
import numpy as np

# %%
usable = master[master['usable'] == 1].copy()

# %%
def with_overalls(df, overall_label='Overall'):
    # Add overall column (sum of each row)
    df2 = df.copy()
    df2[overall_label] = df2.sum(axis=1)
    # Add overall row (sum of each column, including the new column)
    overall_row = df2.sum(axis=0)
    overall_row.name = overall_label
    # Append the overall row
    df2 = pd.concat([df2, overall_row.to_frame().T])
    return df2

# %%
with_overalls(pd.crosstab(usable.status, usable.label))
# Out:
# label               cancer  high_grade  insufficient  low_grade  normal  \
# failed_ext               0           5             6          0      10
# failed_seg               0          11            52          8      81
# features_extracted      26         428          1060        192    1687
# tbp                     17         307           362        147    1497
# Overall                 43         751          1480        347    3275
#
# label               Overall
# failed_ext               21
# failed_seg              152
# features_extracted     3393
# tbp                    2330
# Overall                5896

# %%
# Calculate percentages
percentages = ((pd.crosstab(usable.country, usable.expert_label) / usable.expert_label.value_counts()) * 100).T

# Format with % symbol and round to 2 decimal places
formatted = (percentages.round(1).astype(str) + '%').replace(['0.0%', '0.%'],'')
formatted["Overall"] = "100%"

formatted
# Out:
# country                     Brazil Brasilia Cambodia Dominican Republic  \
# expert_label
# AIS                                            85.7%
# Adenocarcinoma Invasive                        40.0%
# Adenosquamous Carcinoma                                          100.0%
# CIN1                                   7.2%    15.6%              16.7%
# CIN2                                   7.2%    21.7%              13.8%
# CIN3                                   7.4%    34.5%               6.9%
# Insufficient/Inadequate                2.7%     4.0%               4.9%
# Negative/Reactive                      8.1%    26.0%               9.4%
# Other Cancer: Specify
# Other: Specify                                 57.1%              14.3%
# Squamous Invasive Carcinoma            2.9%    52.9%               2.9%
#
# country                     El Salvador Eswatini Honduras Malawi Nigeria  \
# expert_label
# AIS                               14.3%
# Adenocarcinoma Invasive                             20.0%  20.0%   20.0%
# Adenosquamous Carcinoma
# CIN1                              16.7%     2.6%     7.2%  22.8%    8.6%
# CIN2                              22.5%     4.3%     3.6%  18.8%    3.6%
# CIN3                              15.5%     1.3%     3.0%  18.2%    3.1%
# Insufficient/Inadequate           22.6%     0.6%     6.8%  37.8%   16.3%
# Negative/Reactive                 30.5%     2.4%     7.1%          10.5%
# Other Cancer: Specify            100.0%
# Other: Specify                    28.6%
# Squamous Invasive Carcinoma        2.9%              8.8%  11.8%
#
# country                     Tanzania Overall
# expert_label
# AIS                                     100%
# Adenocarcinoma Invasive                 100%
# Adenosquamous Carcinoma                 100%
# CIN1                            2.6%    100%
# CIN2                            4.3%    100%
# CIN3                           10.1%    100%
# Insufficient/Inadequate         4.3%    100%
# Negative/Reactive               6.0%    100%
# Other Cancer: Specify                   100%
# Other: Specify                          100%
# Squamous Invasive Carcinoma    17.6%    100%

# %%
# Calculate percentages
percentages = ((pd.crosstab(usable.country, usable.label) / usable.label.value_counts()) * 100).T

# Format with % symbol and round to 2 decimal places
formatted = (percentages.round(1).astype(str) + '%').replace(['0.0%', '0.%'],'')
formatted["Overall"] = "100%"

formatted
# Out:
# country      Brazil Brasilia Cambodia Dominican Republic El Salvador Eswatini  \
# label
# cancer                  2.3%    51.2%               4.7%        4.7%
# high_grade              7.3%    32.6%               8.1%       16.8%     1.9%
# insufficient            2.7%     4.0%               4.9%       22.6%     0.6%
# low_grade               7.2%    15.6%              16.7%       16.7%     2.6%
# normal                  8.1%    26.0%               9.5%       30.5%     2.4%
#
# country      Honduras Malawi Nigeria Tanzania Overall
# label
# cancer           9.3%  11.6%    2.3%    14.0%    100%
# high_grade       3.1%  18.1%    3.2%     8.9%    100%
# insufficient     6.8%  37.8%   16.3%     4.3%    100%
# low_grade        7.2%  22.8%    8.6%     2.6%    100%
# normal           7.1%          10.5%     6.0%    100%

# %%
pd.crosstab(usable.country, usable.label).T
# Out:
# country       Brazil Brasilia  Cambodia  Dominican Republic  El Salvador  \
# label
# cancer                      1        22                   2            2
# high_grade                 55       245                  61          126
# insufficient               40        59                  73          335
# low_grade                  25        54                  58           58
# normal                    266       852                 310          998
#
# country       Eswatini  Honduras  Malawi  Nigeria  Tanzania
# label
# cancer               0         4       5        1         6
# high_grade          14        23     136       24        67
# insufficient         9       101     559      241        63
# low_grade            9        25      79       30         9
# normal              77       233       0      343       196

# %%
failed_seg = usable[
    usable.status == "failed_seg"
]
pd.crosstab(usable.error, usable.label, dropna=False)
# Out:
# label                  cancer  high_grade  insufficient  low_grade  normal
# error
#  exited unexpectedly        0           1             1          0       2
# Not a JPEG file: sta        0           0             0          0       1
# arts with 0x00 0x00\n       0           4             3          0       8
# axis 0 is out of bou        0           0             1          0       0
# cannot identify imag        0           0             1          0       1
# no_tissue                   0           0            40          0       0
# re end of JPEG file\n       0           0             2          0       0
# too_large                   0          11            10          8      79
# NaN                        43         735          1422        339    3184

# %% [markdown]
# ### Preparing for training

# %%
master.head()
# Out:
#         image_id  usable    label site_label expert_label expert_label_other  \
# 0  PATH000000291       0  Missing    Missing
# 1  PATH000000452       0  Missing    Missing
# 2  PATH000001313       0  Missing    Missing
# 3  PATH000001317       0  Missing    Missing
# 4  PATH000001376       0  Missing    Missing
#
#   expert_label_notes country patient_id  svs_delivered status error
# 0                          .                         1    tbp  <NA>
# 1                          .                         1    tbp  <NA>
# 2                          .                         1    tbp  <NA>
# 3                          .                         1    tbp  <NA>
# 4                          .                         1    tbp  <NA>

# %%
prepped = master[
    (master.status == "features_extracted") &
    master.usable == 1
][['patient_id', 'image_id', 'label', 'country']].rename(
    columns={
        'patient_id': 'case_id',
        'image_id': 'slide_id'
    }
)

# %%
len(prepped)
# Out:
# 3393

# %% [markdown]
# WE CATCH ALL ERRORS FOR MISSING PT FILES, BUT WE STILL WANT TO MAKE SURE ALL THESE ENTRIES EXIST IN THE SYMLINKED DIR.

# %%
pt_files = Path('./pave_training/pathology_features/pt_files')


for slide_id in prepped.slide_id.values:
    if not (pt_files / (slide_id + ".pt")).is_file(): 
        print(f"{slide_id} is not in pt_files, removing from prepped csv.")
        prepped = prepped[
            prepped.slide_id != slide_id
        ]

# %%
prepped.to_csv("/projects/ataghinia@xsede.org/PAVE-Pathology/dataset_csv/pathology_full_subtyping.csv")

# %%
prepped.groupby('label').size()
# Out:
# label
# cancer            26
# high_grade       428
# insufficient    1060
# low_grade        192
# normal          1687
# dtype: int64

# %% [markdown]
# ### Check on status of directories

# %%
import os
import pandas as pd

def num_files(basepath, x, subdir):
    try:
        return len(os.listdir(os.path.join(basepath, x, subdir)))
    except:
        return 0

def subdir_counts(basepath):
    cols = ['wsis','patches','pt_files']
    df = pd.DataFrame(columns=cols)
    
    for x in sorted(os.listdir(basepath)):
        df.loc[x] = [num_files(basepath, x, col) for col in cols]
    
    return df

# %%
subdir_counts("navyblue").T
# Out:
#             A    B    C    D    E    F    G    H    I    J    K    L    M   N  \
# wsis      300  300  300  300  300  300  300  300  300  300  300  300  300  48
# patches   298  296  292  282  280  300  288  296  298  294  298  296  298  47
# pt_files  285  296  283  278  277  300  288  295  298  294  295  295  298  47
#
#           O  P  Q  R  S  T
# wsis      0  0  0  0  0  0
# patches   0  0  0  0  0  0
# pt_files  0  0  0  0  0  0

# %%
subdir_counts("pv3").T
# Out:
#             A    B    C    D    E    F    G    H    I    J    K    L    M  N  \
# wsis      300  300  300  300  300  300  300  300  300  300  300  300  300  8
# patches   281  254  263  298  283  290  290  297  292  291  285  286  294  8
# pt_files  273  253  262  298  282  290  290  297  292  291  285  286  294  8
#
#           O  P  Q
# wsis      0  0  0
# patches   0  0  0
# pt_files  0  0  0

# %% [markdown]
# ### We need to define new CSVs for our three binary classifiers (sufficiency, normalcy, and management)

# %%
sufficiency = prepped.copy()
sufficiency.loc[
    sufficiency.label != "insufficient", 'label'
] = 'sufficient'

# %%
sufficiency['insufficient'] = sufficiency.label == "insufficient"

sufficiency['blurry'] = ((usable.label == "insufficient") & (usable.expert_label_notes.str.contains("blu", case=False)))

sufficiency['mucus'] = ((usable.label == "insufficient") & (usable.expert_label_notes.str.contains("muc", case=False)))

sufficiency['scant_material'] = ((usable.label == "insufficient") & (usable.expert_label_notes.str.contains("mater", case=False)))

sufficiency['scant_cells'] = ((usable.label == "insufficient") & (usable.expert_label_notes.str.contains("cell", case=False)))

sufficiency['inflammation'] = ((usable.label == "insufficient") & (usable.expert_label_notes.str.contains("inf", case=False)))

# %%
print(
    sufficiency[['insufficient','scant_material', 'blurry', 'mucus', 'scant_cells', 'inflammation']].sum(),
    f"\nTotal: {len(sufficiency)}"
)
# Out:
# insufficient      1060
# scant_material     363
# blurry             366
# mucus              260
# scant_cells        148
# inflammation       177
# dtype: int64
# Total: 3393

# %%
sufficiency.label.value_counts()
# Out:
# label
# sufficient      2333
# insufficient    1060
# Name: count, dtype: int64

# %%
normalcy = prepped[prepped.label != 'insufficient'].copy()
normalcy.loc[
    normalcy.label != "normal", 'label'
] = 'abnormal'

# %%
normalcy.label.value_counts()
# Out:
# label
# normal      1687
# abnormal     646
# Name: count, dtype: int64

# %%
management = prepped[prepped.label != 'insufficient'].copy()

management.label = 'follow_up'

management.loc[
    (prepped.label == 'high_grade') | (prepped.label == 'cancer'), 'label'
] = 'treatment'

# %%
management.label.value_counts()
# Out:
# label
# follow_up    1879
# treatment     454
# Name: count, dtype: int64

# %%
management.to_csv("/projects/ataghinia@xsede.org/PAVE-Pathology/dataset_csv/pathology_management.csv")

# %%
sufficiency.to_csv("/projects/ataghinia@xsede.org/PAVE-Pathology/dataset_csv/pathology_sufficiency.csv")

# %%
normalcy.to_csv("/projects/ataghinia@xsede.org/PAVE-Pathology/dataset_csv/pathology_normalcy.csv")

# %% [markdown]
# ### Heatmap Process List

# %%
import pandas as pd

# %%
results = pd.read_csv("/projects/ataghinia@xsede.org/PAVE-Pathology/eval_results/EVAL_normalcy/fold_0.csv")

# %%
full = pd.merge(results, prepped, on='slide_id', how='left')

# %%
full['correct'] = full.Y == full.Y_hat

# %%
sampled = full.groupby(['label','correct']).sample(n=2)

# %%
sampled
# Out:
#           slide_id    Y  Y_hat       p_0       p_1       case_id       label  \
# 92   PATH000008408  1.0    1.0  0.000021  0.999979  PAVE-MW-0243      cancer
# 101  PATH000008198  1.0    1.0  0.000008  0.999992  PAVE-MW-0853      cancer
# 83   PATH000005462  1.0    0.0  0.725520  0.274480   ES1005-0040  high_grade
# 17   PATH000002949  1.0    0.0  0.604371  0.395629     04-5EFCCA  high_grade
# 4    PATH000004370  1.0    1.0  0.003381  0.996619      02-38796  high_grade
# 100  PATH000007640  1.0    1.0  0.002480  0.997520  PAVE-MW-0842  high_grade
# 57   PATH000009986  1.0    0.0  0.826775  0.173225       CMK0789   low_grade
# 71   PATH000005572  1.0    0.0  0.839471  0.160529   ES0714-0042   low_grade
# 49   PATH000008815  1.0    1.0  0.005924  0.994076       CMK0470   low_grade
# 144  PATH000006176  1.0    1.0  0.088258  0.911742       YY02252   low_grade
# 1    PATH000009446  0.0    1.0  0.003901  0.996099      02-00678      normal
# 59   PATH000003249  0.0    1.0  0.315536  0.684464       CSC0152      normal
# 151  PATH000006127  0.0    0.0  0.999915  0.000085       YY05774      normal
# 13   PATH000002663  0.0    0.0  0.999924  0.000076     04-11E049      normal
#
#              country  correct
# 92            Malawi     True
# 101           Malawi     True
# 83       El Salvador    False
# 17          Tanzania    False
# 4    Brazil Brasilia     True
# 100           Malawi     True
# 57          Honduras    False
# 71       El Salvador    False
# 49          Honduras     True
# 144          Nigeria     True
# 1    Brazil Brasilia    False
# 59          Honduras    False
# 151          Nigeria     True
# 13          Tanzania     True

# %%
sampled.to_csv("/projects/ataghinia@xsede.org/PAVE-Pathology/heatmaps/process_lists/normalcy_1_test.csv")

# %%
pd.crosstab(full.Y_hat, full.country) / full.country.value_counts()
# Out:
# country  Brazil Brasilia  Cambodia  Dominican Republic  El Salvador  Eswatini  \
# Y_hat
# 0.0             0.583333  0.527778            0.866667     0.555556       1.0
# 1.0             0.416667  0.472222            0.133333     0.444444       0.0
#
# country  Honduras  Malawi   Nigeria  Tanzania
# Y_hat
# 0.0      0.428571     0.0  0.636364       0.5
# 1.0      0.571429     1.0  0.363636       0.5

# %%
from sklearn.metrics import roc_auc_score

pd.DataFrame(full.groupby('country').apply(
    lambda group: pd.Series({
        'AUC': roc_auc_score(group.Y, group.p_1) if len(np.unique(group.Y)) > 1 else np.nan,
        'Test Cases': len(group)
    }),
    include_groups=False
))
# Out:
#                          AUC  Test Cases
# country
# Brazil Brasilia     0.937500        12.0
# Cambodia            0.971193        36.0
# Dominican Republic  0.846154        15.0
# El Salvador         0.934211        27.0
# Eswatini                 NaN         2.0
# Honduras            0.946970        28.0
# Malawi                   NaN        13.0
# Nigeria             1.000000        11.0
# Tanzania            1.000000         8.0

# %% [markdown]
# ### Investigating Insufficiency Reasons

# %%
usable[
    usable.label == "insufficient"
].sample(50)
# Out:
#             image_id  usable         label           site_label  \
# 11762  PATH000007479       1  insufficient               Normal
# 5067   PATH000003084       1  insufficient                 CIN1
# 11291  PATH000004655       1  insufficient               Normal
# 9595   PATH000003638       1  insufficient               Normal
# 776    PATH000009949       1  insufficient           Cervicitis
# 7610   PATH000002136       1  insufficient               Normal
# 14150  PATH000006120       1  insufficient                 CIN1
# 8850   PATH000004125       1  insufficient                 CIN3
# 6432   PATH000012077       1  insufficient                 CIN1
# 4896   PATH000008894       1  insufficient                 CIN1
# 9252   PATH000004296       1  insufficient                 CIN1
# 13849  PATH000008438       1  insufficient           Cervicitis
# 10006  PATH000005368       1  insufficient           Cervicitis
# 5454   PATH000009643       1  insufficient               Normal
# 12647  PATH000003566       1  insufficient           Cervicitis
# 9566   PATH000003940       1  insufficient               Normal
# 7809   PATH000012250       1  insufficient                 CIN2
# 10302  PATH000007062       1  insufficient               Normal
# 11265  PATH000004519       1  insufficient                 CIN3
# 5062   PATH000003187       1  insufficient               Normal
# 14721  PATH000006268       1  insufficient                 CIN1
# 10357  PATH000007476       1  insufficient                 CIN3
# 15330  PATH000008462       1  insufficient           Cervicitis
# 5156   PATH000002631       1  insufficient                 CIN1
# 10740  PATH000004073       1  insufficient               Normal
# 14169  PATH000006370       1  insufficient                 CIN1
# 11033  PATH000004701       1  insufficient               Normal
# 3287   PATH000003865       1  insufficient                 CIN1
# 7283   PATH000005215       1  insufficient                 CIN1
# 9738   PATH000008184       1  insufficient               Normal
# 8924   PATH000005353       1  insufficient                 CIN3
# 4570   PATH000009183       1  insufficient                 CIN1
# 9190   PATH000003673       1  insufficient                 CIN1
# 5096   PATH000003218       1  insufficient                 CIN1
# 11083  PATH000005606       1  insufficient                 CIN1
# 9110   PATH000004500       1  insufficient               Normal
# 13618  PATH000003231       1  insufficient  Sample Insufficient
# 14513  PATH000006360       1  insufficient           Cervicitis
# 9090   PATH000003816       1  insufficient               Normal
# 8409   PATH000012564       1  insufficient                 CIN1
# 9152   PATH000004791       1  insufficient           Cervicitis
# 8064   PATH000005793       1  insufficient                 CIN3
# 11634  PATH000004274       1  insufficient                 CIN3
# 2566   PATH000000689       1  insufficient       Other(specify)
# 14779  PATH000006377       1  insufficient               Normal
# 8096   PATH000000591       1  insufficient                 CIN1
# 15387  PATH000008686       1  insufficient           Cervicitis
# 1325   PATH000009635       1  insufficient                 CIN1
# 11003  PATH000003937       1  insufficient               Normal
# 4512   PATH000009005       1  insufficient  Sample Insufficient
#
#                   expert_label expert_label_other  \
# 11762  Insufficient/Inadequate
# 5067   Insufficient/Inadequate
# 11291  Insufficient/Inadequate
# 9595   Insufficient/Inadequate
# 776    Insufficient/Inadequate
# 7610   Insufficient/Inadequate
# 14150  Insufficient/Inadequate
# 8850   Insufficient/Inadequate
# 6432   Insufficient/Inadequate
# 4896   Insufficient/Inadequate
# 9252   Insufficient/Inadequate
# 13849  Insufficient/Inadequate
# 10006  Insufficient/Inadequate
# 5454   Insufficient/Inadequate
# 12647  Insufficient/Inadequate
# 9566   Insufficient/Inadequate
# 7809   Insufficient/Inadequate
# 10302  Insufficient/Inadequate
# 11265  Insufficient/Inadequate
# 5062   Insufficient/Inadequate
# 14721  Insufficient/Inadequate
# 10357  Insufficient/Inadequate
# 15330  Insufficient/Inadequate
# 5156   Insufficient/Inadequate
# 10740  Insufficient/Inadequate
# 14169  Insufficient/Inadequate
# 11033  Insufficient/Inadequate
# 3287   Insufficient/Inadequate
# 7283   Insufficient/Inadequate
# 9738   Insufficient/Inadequate
# 8924   Insufficient/Inadequate
# 4570   Insufficient/Inadequate
# 9190   Insufficient/Inadequate
# 5096   Insufficient/Inadequate
# 11083  Insufficient/Inadequate
# 9110   Insufficient/Inadequate
# 13618  Insufficient/Inadequate
# 14513  Insufficient/Inadequate
# 9090   Insufficient/Inadequate
# 8409   Insufficient/Inadequate
# 9152   Insufficient/Inadequate
# 8064   Insufficient/Inadequate
# 11634  Insufficient/Inadequate
# 2566   Insufficient/Inadequate
# 14779  Insufficient/Inadequate
# 8096   Insufficient/Inadequate
# 15387  Insufficient/Inadequate
# 1325   Insufficient/Inadequate
# 11003  Insufficient/Inadequate
# 4512   Insufficient/Inadequate
#
#                                    expert_label_notes             country  \
# 11762                               SCANT CELLULARITY              Malawi
# 5067                              OUT OF FOCUS/RESCAN            Honduras
# 11291                                                              Malawi
# 9595                                                               Malawi
# 776                           MUCUS SCANT CELLULARITY     Brazil Brasilia
# 7610                               MUCUS INFLAMMATION         El Salvador
# 14150                                   BLURRY RESCAN             Nigeria
# 8850                                           BLURRY              Malawi
# 6432                          MUCUS SCANT CELLULARITY         El Salvador
# 4896                               MUCUS INFLAMMATION  Dominican Republic
# 9252                          MUCUS SCANT CELLULARITY              Malawi
# 13849                                  SCANT MATERIAL             Nigeria
# 10006             MUCUS INFLAMMATION SCANT EPITHELIUM              Malawi
# 5454                               MUCUS INFLAMMATION            Honduras
# 12647                                  SCANT MATERIAL            Cambodia
# 9566                                   BLURRY RE SCAN              Malawi
# 7809                                      MUCUS BLOOD         El Salvador
# 10302                                   BLURRY RESCAN              Malawi
# 11265                                   BLURRY RESCAN              Malawi
# 5062                                      NO MATERIAL            Honduras
# 14721                                   BLURRY RESCAN             Nigeria
# 10357                           BLURRY SCANT MATERIAL              Malawi
# 15330                                   BLURRY RESCAN             Nigeria
# 5156                           MUCUS AND INFLAMMATION            Honduras
# 10740                                        NO CELLS              Malawi
# 14169                                     NO MATERIAL             Nigeria
# 11033                           BLURRY SCANT MATERIAL              Malawi
# 3287                       BAD QUALITY SECTION. RECUT            Tanzania
# 7283                                    BLURRY RESCAN         El Salvador
# 9738                                    BLURRY RESCAN              Malawi
# 8924                            BLURRY SCANT MATERIAL              Malawi
# 4570                             MUCUS SCANT MATERIAL  Dominican Republic
# 9190                                   SCANT MATERIAL              Malawi
# 5096                               MUCUS INFLAMMATION            Honduras
# 11083                    BLURRY SCANT MATERIAL RESCAN              Malawi
# 9110                               MUCUS INFLAMMATION              Malawi
# 13618                              MUCUS INFLAMMATION            Eswatini
# 14513                              MUCUS INFLAMMATION             Nigeria
# 9090                                   SCANT MATERIAL              Malawi
# 8409                                      NO MATERIAL         El Salvador
# 9152                                           BLURRY              Malawi
# 8064                                    BLURRY RESCAN         El Salvador
# 11634                                  SCANT MATERIAL              Malawi
# 2566   ENDOMETRIUM OF THE SEGMENT/ IRREGULAR SCANNING            Tanzania
# 14779                    BLURRY RESCAN SCANT MATERIAL             Nigeria
# 8096                                                          El Salvador
# 15387                           BLURRY SCANT MATERIAL             Nigeria
# 1325                                SCANT CELLULARITY     Brazil Brasilia
# 11003                               SCANT CELLULARITY              Malawi
# 4512                                            MUCUS  Dominican Republic
#
#          patient_id  svs_delivered              status      error
# 11762  PAVE-MW-0934              1  features_extracted       <NA>
# 5067        CMK0067              1  features_extracted       <NA>
# 11291  PAVE-MW-0810              1  features_extracted       <NA>
# 9595   PAVE-MW-0209              1  features_extracted       <NA>
# 776        02-04978              1  features_extracted       <NA>
# 7610    ES0902-0023              1                 tbp       <NA>
# 14150       YY01402              1  features_extracted       <NA>
# 8850   PAVE-MW-0020              1  features_extracted       <NA>
# 6432    ES0707-0011              1                 tbp       <NA>
# 4896       302-1571              1  features_extracted       <NA>
# 9252   PAVE-MW-0123              1  features_extracted       <NA>
# 13849       YY00154              1  features_extracted       <NA>
# 10006  PAVE-MW-0313              1  features_extracted       <NA>
# 5454        CMK0648              1  features_extracted       <NA>
# 12647  PID 07-03178              1  features_extracted       <NA>
# 9566   PAVE-MW-0206              1  features_extracted       <NA>
# 7809   ES09038-0017              1                 tbp       <NA>
# 10302  PAVE-MW-0409              1  features_extracted       <NA>
# 11265  PAVE-MW-0806              1  features_extracted       <NA>
# 5062        CMK0063              1  features_extracted       <NA>
# 14721       YY03870              1  features_extracted       <NA>
# 10357  PAVE-MW-0417              1  features_extracted       <NA>
# 15330       YY06508              1  features_extracted       <NA>
# 5156        CMK0161              1                 tbp       <NA>
# 10740  PAVE-MW-0601              1  features_extracted       <NA>
# 14169       YY01463              1          failed_seg  too_large
# 11033  PAVE-MW-0705              1  features_extracted       <NA>
# 3287      04-77AC86              1  features_extracted       <NA>
# 7283   ES08162-0016              1  features_extracted       <NA>
# 9738   PAVE-MW-0235              1  features_extracted       <NA>
# 8924   PAVE-MW-0037              1          failed_seg  no_tissue
# 4570       302-1370              1  features_extracted       <NA>
# 9190   PAVE-MW-0113              1  features_extracted       <NA>
# 5096        CMK0102              1  features_extracted       <NA>
# 11083  PAVE-MW-0713              1  features_extracted       <NA>
# 9110   PAVE-MW-0105              1  features_extracted       <NA>
# 13618  SWZ-L016-006              1  features_extracted       <NA>
# 14513       YY03031              1  features_extracted       <NA>
# 9090   PAVE-MW-0102              1  features_extracted       <NA>
# 8409    ES1006-0047              1                 tbp       <NA>
# 9152   PAVE-MW-0109              1  features_extracted       <NA>
# 8064   ES09071-0017              1  features_extracted       <NA>
# 11634  PAVE-MW-0907              1  features_extracted       <NA>
# 2566      04-000267              1                 tbp       <NA>
# 14779       YY04143              1  features_extracted       <NA>
# 8096    ES0908-0010              1                 tbp       <NA>
# 15387       YY06721              1  features_extracted       <NA>
# 1325       02-17280              1  features_extracted       <NA>
# 11003  PAVE-MW-0701              1  features_extracted       <NA>
# 4512       302-1336              1  features_extracted       <NA>

# %%
import pandas as pd
from collections import Counter
import re # For cleaning text (e.g., removing extra whitespace if desired)

def get_most_common_char_ngrams(df: pd.DataFrame, column_name: str, 
                                  n: int = 3, top_n: int = 10,
                                  lowercase: bool = True, remove_extra_whitespace: bool = True) -> list:
    """
    Finds the most common character N-grams (substrings of a fixed length 'n')
    in a specified column of a Pandas DataFrame.

    Args:
        df (pd.DataFrame): The input DataFrame.
        column_name (str): The name of the text column to analyze.
        n (int): The length of the character N-gram (substring) to find. Defaults to 3 (trigrams).
        top_n (int): The number of most common N-grams to return. Defaults to 10.
        lowercase (bool): If True, convert text to lowercase before processing. Defaults to True.
        remove_extra_whitespace (bool): If True, replace multiple spaces/tabs/newlines
                                        with a single space and strip leading/trailing whitespace.
                                        This affects how substrings with spaces are counted. Defaults to True.

    Returns:
        list: A list of tuples, where each tuple is ('substring', count)
              representing the character N-gram and its frequency, sorted by count
              in descending order.
              Returns an empty list if the column is not found or contains no valid text.
    """
    if column_name not in df.columns:
        print(f"Error: Column '{column_name}' not found in DataFrame.")
        return []

    if n <= 0:
        raise ValueError("The character N-gram length 'n' must be a positive integer.")

    all_ngrams = []

    # Process each text entry in the specified column
    for text in df[column_name].dropna(): # .dropna() handles NaN/None values
        # Ensure text is a string before processing
        if not isinstance(text, str):
            continue

        if lowercase:
            text = text.lower()

        if remove_extra_whitespace:
            # Replace multiple whitespace characters (including newlines, tabs) with a single space
            # and strip leading/trailing whitespace
            text = re.sub(r'\s+', ' ', text).strip()

        # Generate character N-grams
        # Iterate from the start of the string up to the point where an n-gram can be formed
        for i in range(len(text) - n + 1):
            ngram = text[i : i + n]
            all_ngrams.append(ngram)

    # Count the frequency of each N-gram
    ngram_counts = Counter(all_ngrams)

    # Return the top N most common N-grams
    return ngram_counts.most_common(top_n)

# %%
n = 5

print(f"Most common 50 character {n}grams:\n")
common_trigrams = get_most_common_char_ngrams(
    usable[
        usable.label == "insufficient"
    ], 
    'expert_label_notes', 
    n=n, 
    top_n=50
)
for ngram, count in common_trigrams:
    print(f"'{ngram}': {count}")
print("\n" + "="*50 + "\n")
# Out:
# Most common 50 character 5grams:
#
# 'scant': 579
# 'cant ': 576
# 'ateri': 477
# 'teria': 477
# 'erial': 477
# ' mate': 476
# 'mater': 476
# 'lurry': 456
# 'blurr': 453
# 'urry ': 387
# 'ant m': 378
# 'nt ma': 378
# 't mat': 378
# 'mucus': 348
# ' scan': 319
# 'ucus ': 310
# 'resca': 283
# 'escan': 283
# ' resc': 276
# ' cell': 244
# 'rry r': 239
# 'ry re': 239
# 'y res': 226
# 'ation': 216
# 'infla': 214
# 'nflam': 214
# 'flamm': 214
# 'lamma': 214
# 'ammat': 214
# 'mmati': 214
# 'matio': 214
# ' infl': 212
# 'lular': 196
# 'cellu': 195
# 'ellul': 195
# 'llula': 195
# 'ulari': 183
# 'larit': 183
# 'arity': 183
# 'cus i': 178
# 'us in': 178
# 's inf': 178
# 'ant c': 175
# 'nt ce': 175
# 't cel': 174
# 'y sca': 118
# 'ry sc': 117
# 'rry s': 114
# 'blood': 94
# 'no ma': 89
#
# ==================================================

# %%
usable['blurry'] = ((usable.label == "insufficient") & (usable.expert_label_notes.str.contains("blu", case=False)))

usable['mucus'] = ((usable.label == "insufficient") & (usable.expert_label_notes.str.contains("muc", case=False)))

usable['scant_material'] = ((usable.label == "insufficient") & (usable.expert_label_notes.str.contains("mater", case=False)))

usable['scant_cells'] = ((usable.label == "insufficient") & (usable.expert_label_notes.str.contains("cell", case=False)))

usable['inflammation'] = ((usable.label == "insufficient") & (usable.expert_label_notes.str.contains("inf", case=False)))

# %%
insuff = usable[
    usable.label == 'insufficient'
]

print(insuff[['scant_material', 'blurry', 'mucus', 'scant_cells', 'inflammation']].sum(), f"\nTotal: {len(insuff)}")
# Out:
# scant_material    475
# blurry            450
# mucus             347
# scant_cells       254
# inflammation      213
# dtype: int64
# Total: 1480

# %%
insuff[
    ['scant_material', 'blurry', 'mucus', 'scant_cells', 'inflammation']
].corr()
# Out:
#                 scant_material    blurry     mucus  scant_cells  inflammation
# scant_material        1.000000 -0.023364 -0.281392    -0.309083     -0.248894
# blurry               -0.023364  1.000000 -0.365795    -0.285274     -0.271012
# mucus                -0.281392 -0.365795  1.000000     0.226071      0.727256
# scant_cells          -0.309083 -0.285274  0.226071     1.000000      0.002270
# inflammation         -0.248894 -0.271012  0.727256     0.002270      1.000000

# %%
unsorted = insuff[
        ~insuff.scant_material & ~insuff.blurry & ~insuff.mucus & ~insuff.scant_cells & ~insuff.inflammation
    ]

len(unsorted)
# Out:
# 235

# %%
len(unsorted[
unsorted.expert_label_notes.str.contains("foc", case=False)
    ])
# Out:
# 34

# %%
n=8

get_most_common_char_ngrams(
    insuff[
        ~insuff.scant_material & ~insuff.blurry & ~insuff.mucus & ~insuff.scant_cells & ~insuff.inflammation
    ],
    'expert_label_notes', 
    n=n, 
    top_n=50
)
# Out:
# [('out of f', 34),
#  ('ut of fo', 34),
#  ('t of foc', 34),
#  (' of focu', 34),
#  ('of focus', 34),
#  ('endometr', 28),
#  ('ndometri', 28),
#  ('bad qual', 27),
#  ('ad quali', 27),
#  ('d qualit', 27),
#  (' quality', 27),
#  ('quality ', 25),
#  ('f focus ', 20),
#  ('uality s', 20),
#  (' focus r', 19),
#  ('focus re', 19),
#  ('dometriu', 16),
#  ('ometrium', 16),
#  ('s rescan', 16),
#  ('ality sl', 16),
#  ('lity sli', 16),
#  ('ity slid', 16),
#  ('ty slide', 16),
#  ('ocus res', 15),
#  ('cus resc', 15),
#  ('us resca', 15),
#  (' endomet', 14),
#  ('scanning', 12),
#  ('dometria', 12),
#  ('ometrial', 12),
#  ('metrial ', 12),
#  (' artifac', 12),
#  ('artifact', 12),
#  ('staining', 12),
#  (' scannin', 11),
#  (' stainin', 11),
#  ('etrial t', 10),
#  ('trial ti', 10),
#  ('rial tis', 10),
#  ('ial tiss', 10),
#  ('al tissu', 10),
#  ('l tissue', 10),
#  ('scant en', 9),
#  ('cant end', 9),
#  ('ant endo', 9),
#  (' endocer', 9),
#  ('endocerv', 9),
#  ('ndocervi', 9),
#  ('bubble a', 9),
#  ('ubble ar', 9)]
